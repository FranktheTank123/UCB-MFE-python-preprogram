# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import datetime

from datetime import timedelta

# %% [markdown]
# Please do the following in a jupyter notebook
#
# - There is a csv under the data folder called hw3.csv
# - the goal of this hw is to calculate volumeUSD by chain
#
# Some hints for this hw:
#
# - volumeUSD = volume * close
# - you will need to clean data
# - visualize your data to better understand what is going on

# %%
df = pd.read_csv("../../../Lectures/Lecture 3/data/hw3.csv")

# %%
df.head()
# Out:
#                     ts       open       high        low      close  \
# 0  2021-12-02 14:00:00    22.4150    22.4913    22.0816    22.3516
# 1  2021-12-02 23:00:00     4.8043     4.8043     4.7426     4.7806
# 2  2021-12-10 15:00:00   182.4900        NaN   175.2100   175.8600
# 3  2021-12-10 18:00:00  3978.4300  3989.7400  3932.0000  3972.3400
# 4  2021-12-08 21:00:00   193.3240   194.2420   192.5640   193.1540
#
#          volume  volumeUSD token chain
# 0  31502.151631        NaN   UNI   ETH
# 1  73686.230000        NaN   CRV   ETH
# 2  73736.747000        NaN   SOL   SOL
# 3  18508.040102        NaN   ETH   ETH
# 4  69426.909000        NaN   SOL   SOL

# %%
# As we work with time series, let's sort the data by timestamp
df['ts'] = pd.to_datetime(df['ts'])
df.sort_values('ts', inplace=True)
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#           ts        open        high         low       close        volume  \
# 0 2021-12-01    210.3120         NaN    208.4320    208.6760  70031.618000
# 1 2021-12-01    280.5900    281.4000    278.3000    278.7000    207.849000
# 2 2021-12-01    257.1020    260.7750    255.3450    257.0780   2730.299000
# 3 2021-12-01     21.2004     21.3115     21.0337     21.2659  12406.133674
# 4 2021-12-01  57321.4100  57451.0500  56814.3400  56987.9700    388.482022
#
#    volumeUSD token chain
# 0        NaN   SOL   SOL
# 1        NaN  COMP   ETH
# 2        NaN  AAVE   ETH
# 3        NaN   UNI   ETH
# 4        NaN   BTC   BTC

# %%
# Let's check the size of the dataframe
df.shape
# Out:
# (2667, 9)

# %%
# And available chains
set(df['chain'])
# Out:
# {'BTC', 'ETH', 'SOL', 'USDT'}

# %%
# Calculate the volume
df['volumeUSD'] = df['close'] * df['volume']

# %%
volume_initial = df.groupby('chain').sum()['volumeUSD'].to_frame().sort_values('volumeUSD', 
                                                              ascending=False)
volume_initial.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_c1169_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >volumeUSD</th>    </tr>    <tr>        <th class="index_name level0" >chain</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1169_level0_row0" class="row_heading level0 row0" >BTC</th>
#                         <td id="T_c1169_row0_col0" class="data row0 col0" >46,684,524,066</td>
#             </tr>
#             <tr>
#                         <th id="T_c1169_level0_row1" class="row_heading level0 row1" >ETH</th>
#                         <td id="T_c1169_row1_col0" class="data row1 col0" >20,469,314,784</td>
#             </tr>
#             <tr>
#                         <th id="T_c1169_level0_row2" class="row_heading level0 row2" >SOL</th>
#                         <td id="T_c1169_row2_col0" class="data row2 col0" >7,172,882,528</td>
#             </tr>
#             <tr>
#                         <th id="T_c1169_level0_row3" class="row_heading level0 row3" >USDT</th>
#                         <td id="T_c1169_row3_col0" class="data row3 col0" >1,557,237,812</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Let's check whether there are some NaNs for volumeUSD

# %%
df[df['volumeUSD'].isnull()]
# Out:
#                       ts        open        high         low  close  \
# 54   2021-12-01 06:00:00      5.2505      5.3002      5.1566    NaN
# 64   2021-12-01 07:00:00   4707.7400   4750.0000   4691.6200    NaN
# 115  2021-12-01 12:00:00    264.9130    264.9260    261.8000    NaN
# 149  2021-12-01 16:00:00    268.7450    269.1060    264.8280    NaN
# 165  2021-12-01 18:00:00  58485.8800  58631.4000  58007.2400    NaN
# ...                  ...         ...         ...         ...    ...
# 2598 2021-12-12 23:00:00      1.0006         NaN      1.0005    NaN
# 2611 2021-12-13 00:00:00    180.5100    181.1900         NaN    NaN
# 2639 2021-12-13 04:00:00    191.8500    192.8700    191.1900    NaN
# 2662 2021-12-13 06:00:00      3.8700      3.8700      3.8200    NaN
# 2663 2021-12-13 06:00:00      3.8700      3.8700      3.8200    NaN
#
#              volume  volumeUSD                              token chain
# 54    389798.700000        NaN                                CRV   ETH
# 64      8911.031559        NaN  <span name="tokenName">ETH</span>   ETH
# 115     1019.545000        NaN                               AAVE   ETH
# 149     2063.599000        NaN                               AAVE   ETH
# 165      633.239868        NaN                                BTC   BTC
# ...             ...        ...                                ...   ...
# 2598  861409.230000        NaN                               USDT  USDT
# 2611    1016.050000        NaN                               AAVE   ETH
# 2639    1046.025000        NaN                               COMP   ETH
# 2662   45270.080000        NaN                                CRV   ETH
# 2663   45270.080000        NaN                                CRV   ETH
#
# [136 rows x 9 columns]

# %% [markdown]
# As we have 2 variables: price and volume, then there are 2 possible sources of NaNs. Let's check both

# %%
df[df['volumeUSD'].isnull()&df['close'].isnull()]
# Out:
#                       ts        open        high         low  close  \
# 54   2021-12-01 06:00:00      5.2505      5.3002      5.1566    NaN
# 64   2021-12-01 07:00:00   4707.7400   4750.0000   4691.6200    NaN
# 115  2021-12-01 12:00:00    264.9130    264.9260    261.8000    NaN
# 149  2021-12-01 16:00:00    268.7450    269.1060    264.8280    NaN
# 165  2021-12-01 18:00:00  58485.8800  58631.4000  58007.2400    NaN
# ...                  ...         ...         ...         ...    ...
# 2598 2021-12-12 23:00:00      1.0006         NaN      1.0005    NaN
# 2611 2021-12-13 00:00:00    180.5100    181.1900         NaN    NaN
# 2639 2021-12-13 04:00:00    191.8500    192.8700    191.1900    NaN
# 2662 2021-12-13 06:00:00      3.8700      3.8700      3.8200    NaN
# 2663 2021-12-13 06:00:00      3.8700      3.8700      3.8200    NaN
#
#              volume  volumeUSD                              token chain
# 54    389798.700000        NaN                                CRV   ETH
# 64      8911.031559        NaN  <span name="tokenName">ETH</span>   ETH
# 115     1019.545000        NaN                               AAVE   ETH
# 149     2063.599000        NaN                               AAVE   ETH
# 165      633.239868        NaN                                BTC   BTC
# ...             ...        ...                                ...   ...
# 2598  861409.230000        NaN                               USDT  USDT
# 2611    1016.050000        NaN                               AAVE   ETH
# 2639    1046.025000        NaN                               COMP   ETH
# 2662   45270.080000        NaN                                CRV   ETH
# 2663   45270.080000        NaN                                CRV   ETH
#
# [136 rows x 9 columns]

# %%
df[df['volumeUSD'].isnull()&df['volume'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ts, open, high, low, close, volume, volumeUSD, token, chain]
# Index: []

# %% [markdown]
# So the problem is only in close prices. Let's zoom some cases

# %%
problem_index = df[df['volumeUSD'].isnull()&df['close'].isnull()].index

# %% [markdown]
# We see that there are 2 types of problems:
# - Missing price
# - Incorrectly parsed toke name

# %%
df.iloc[problem_index[:5], :]
# Out:
#                      ts        open        high         low  close  \
# 54  2021-12-01 06:00:00      5.2505      5.3002      5.1566    NaN
# 64  2021-12-01 07:00:00   4707.7400   4750.0000   4691.6200    NaN
# 115 2021-12-01 12:00:00    264.9130    264.9260    261.8000    NaN
# 149 2021-12-01 16:00:00    268.7450    269.1060    264.8280    NaN
# 165 2021-12-01 18:00:00  58485.8800  58631.4000  58007.2400    NaN
#
#             volume  volumeUSD                              token chain
# 54   389798.700000        NaN                                CRV   ETH
# 64     8911.031559        NaN  <span name="tokenName">ETH</span>   ETH
# 115    1019.545000        NaN                               AAVE   ETH
# 149    2063.599000        NaN                               AAVE   ETH
# 165     633.239868        NaN                                BTC   BTC

# %%
# Let's fix it

def fix_prices(problem_index, df):
    '''
    This function is used to replace NaN close prices with the preceeding ones.
    
    Args:
    problem_index (list) - list of indices with NaN prices
    df (DataFrame) - initial dataframe
    
    Outputs:
    df_adj (DataFrame) - final dataframe with fixed prices
    '''

    for i in problem_index:
        ts_tmp = df.loc[i, 'ts']
        ts_adj = ts_tmp - timedelta(hours=1)

        chain_tmp = df.loc[i, 'chain']
        token_tmp = df.loc[i, 'token']
        
        # Remove broken token name
        if "span name" in token_tmp:
            df.loc[i, 'token'] = token_tmp.split('>')[1].split('<')[0]
            
        # Calculate the previous price
        try:
            previous_price = df[(df['ts'] < df.loc[i, 'ts'])&
                                (df['chain'] == df.loc[i, 'chain'])&
                                (df['token'] == df.loc[i, 'token'])]['close'].values[-1]

            df.loc[i, 'close'] = previous_price
        except IndexError:
            print('Does not work for case {}, ts {}, chain {}, token {}'.format(i, ts_tmp, 
                                                                                chain_tmp, token_tmp))

    # Recalculate the volume
    df['volumeUSD'] = df['close'] * df['volume']
    
    return df

# %%
df = fix_prices(problem_index, df)

# %%
# So we see that we removed all problems
df[df['volumeUSD'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ts, open, high, low, close, volume, volumeUSD, token, chain]
# Index: []

# %%
volume_final = df.groupby('chain').sum()['volumeUSD'].to_frame().sort_values('volumeUSD', 
                                                              ascending=False)
volume_final.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_47263_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >volumeUSD</th>    </tr>    <tr>        <th class="index_name level0" >chain</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_47263_level0_row0" class="row_heading level0 row0" >BTC</th>
#                         <td id="T_47263_row0_col0" class="data row0 col0" >49,454,021,505</td>
#             </tr>
#             <tr>
#                         <th id="T_47263_level0_row1" class="row_heading level0 row1" >ETH</th>
#                         <td id="T_47263_row1_col0" class="data row1 col0" >21,525,201,689</td>
#             </tr>
#             <tr>
#                         <th id="T_47263_level0_row2" class="row_heading level0 row2" >SOL</th>
#                         <td id="T_47263_row2_col0" class="data row2 col0" >7,475,235,361</td>
#             </tr>
#             <tr>
#                         <th id="T_47263_level0_row3" class="row_heading level0 row3" >USDT</th>
#                         <td id="T_47263_row3_col0" class="data row3 col0" >1,656,244,971</td>
#             </tr>
#     </tbody></table>

# %%
# This is the % of volume we fixed
round((volume_final / volume_initial - 1) * 100, 2)
# Out:
#        volumeUSD
# chain
# BTC         5.93
# ETH         5.16
# SOL         4.22
# USDT        6.36
