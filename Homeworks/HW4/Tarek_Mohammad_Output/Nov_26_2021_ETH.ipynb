# %%
import pandas as pd
import numpy as np
import sqlite3
import gspread
import scrapbook as sb

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.dates import date2num, DateFormatter
#from pandas.plotting import scatter_matrix

plt.style.use('ggplot')
plt.tight_layout()
plt.rcParams['figure.figsize'] = [20, 20]

# %matplotlib inline
# Out:
# C:\Users\USP\anaconda3\lib\site-packages\papermill\iorw.py:50: FutureWarning: pyarrow.HadoopFileSystem is deprecated as of 2.0.0, please use pyarrow.fs.HadoopFileSystem instead.
#   from pyarrow import HadoopFileSystem

# %% [markdown]
# ### Identifying our data limits:

# %%
connection_string = 'sqlite:///data/data.db'

# %%
prices = pd.read_sql(f'''
SELECT 
    * 
FROM ohlc 
''', connection_string)
prices['ts'] = pd.to_datetime(prices['ts'])

prices.set_index('ts', inplace=True)

# %%
prices.tail(336)
# Out:
#                        open    high     low   close    volume     volumeUSD  \
# ts
# 2021-12-01 01:00:00  278.65  283.80  276.36  283.44   817.668  229274.61550
# 2021-12-01 02:00:00  283.20  283.20  280.61  281.29   254.330   71609.32568
# 2021-12-01 03:00:00  281.25  283.22  279.90  283.09   393.771  110890.74168
# 2021-12-01 04:00:00  283.10  284.16  282.60  283.73   489.120  138532.76788
# 2021-12-01 05:00:00  283.84  284.46  281.95  282.57   185.039   52374.85772
# ...                     ...     ...     ...     ...       ...           ...
# 2021-12-14 20:00:00  178.99  181.27  178.72  180.28   628.699  113081.48965
# 2021-12-14 21:00:00  180.15  183.76  179.96  183.43  2453.455  444711.90422
# 2021-12-14 22:00:00  183.31  186.74  182.60  185.24  2086.017  386571.01446
# 2021-12-14 23:00:00  185.22  186.09  183.88  185.08   416.028   76987.19948
# 2021-12-15 00:00:00  185.07  185.78  184.50  184.89   335.307   62142.63926
#
#                     token chain
# ts
# 2021-12-01 01:00:00  COMP   ETH
# 2021-12-01 02:00:00  COMP   ETH
# 2021-12-01 03:00:00  COMP   ETH
# 2021-12-01 04:00:00  COMP   ETH
# 2021-12-01 05:00:00  COMP   ETH
# ...                   ...   ...
# 2021-12-14 20:00:00  COMP   ETH
# 2021-12-14 21:00:00  COMP   ETH
# 2021-12-14 22:00:00  COMP   ETH
# 2021-12-14 23:00:00  COMP   ETH
# 2021-12-15 00:00:00  COMP   ETH
#
# [336 rows x 8 columns]

# %% [markdown]
# * The last 2 weeks of our df range from 2021-12-01 to 2021-12-14

# %%
print("We have the following tokens in our df: ")

list(dict(prices.groupby("token").size()).keys())
# Out:
# We have the following tokens in our df:
# ['AAVE',
#  'ADA',
#  'ATOM',
#  'AVAX',
#  'BTC',
#  'COMP',
#  'CRV',
#  'DOT',
#  'ETH',
#  'SOL',
#  'USDT']

# %%
token = 'BTC'
from_date = '2021-11-05'
to_date = '2021-11-12'
connection_string = 'sqlite:///data/data.db'

# %%
# Parameters
from_date = "2021-11-26 00:00:00"
to_date = "2021-12-03 00:00:00"
token = "ETH"
connection_string = "sqlite:///data/data.db"

# %%
prices = pd.read_sql(f'''
SELECT 
    * 
FROM ohlc 
WHERE 
    token = '{token}'
    AND ts >= '{from_date}'
    AND ts < '{to_date}'
''', connection_string)
prices['ts'] = pd.to_datetime(prices['ts'])

prices.set_index('ts', inplace=True)

# %%
prices
# Out:
#                         open     high      low    close        volume  \
# ts
# 2021-11-26 00:00:00  4520.77  4555.11  4512.01  4525.87   5931.964221
# 2021-11-26 01:00:00  4527.03  4555.53  4493.42  4501.61   8778.167630
# 2021-11-26 02:00:00  4501.12  4524.03  4489.06  4489.68   6501.617215
# 2021-11-26 03:00:00  4489.23  4504.44  4455.38  4461.07   5350.262486
# 2021-11-26 04:00:00  4460.82  4473.83  4428.32  4429.85   5502.642751
# ...                      ...      ...      ...      ...           ...
# 2021-12-02 19:00:00  4496.68  4498.15  4435.00  4483.59  12659.707261
# 2021-12-02 20:00:00  4483.57  4509.11  4476.16  4490.75   7955.847565
# 2021-12-02 21:00:00  4490.80  4544.04  4472.59  4539.06   9404.595130
# 2021-12-02 22:00:00  4539.51  4556.45  4522.88  4546.65   7666.398809
# 2021-12-02 23:00:00  4546.65  4559.84  4525.00  4545.07   5521.361836
#
#                         volumeUSD token chain
# ts
# 2021-11-26 00:00:00  2.688868e+07   ETH   ETH
# 2021-11-26 01:00:00  3.969569e+07   ETH   ETH
# 2021-11-26 02:00:00  2.929044e+07   ETH   ETH
# 2021-11-26 03:00:00  2.401037e+07   ETH   ETH
# 2021-11-26 04:00:00  2.449721e+07   ETH   ETH
# ...                           ...   ...   ...
# 2021-12-02 19:00:00  5.651965e+07   ETH   ETH
# 2021-12-02 20:00:00  3.574223e+07   ETH   ETH
# 2021-12-02 21:00:00  4.249628e+07   ETH   ETH
# 2021-12-02 22:00:00  3.480727e+07   ETH   ETH
# 2021-12-02 23:00:00  2.506029e+07   ETH   ETH
#
# [168 rows x 8 columns]

# %% [markdown]
# ### Functionalities:

# %% [markdown]
# #### Returns:

# %%
# func for returns:

def ret_ohlc(df):
    o = df.open
    h = df.high
    l = df.low
    c = df.close
    
    # return for each column
    oo = np.log(o/o.shift(1))
    hh = np.log(h/h.shift(1))
    ll = np.log(l/l.shift(1))
    cc = np.log(c/c.shift(1))
    
    return oo, hh, ll, cc

# %%
oo, hh, ll, cc = ret_ohlc(prices)

# %% [markdown]
# #### Volatility:

# %%
# func for volatility:

def vol_ohlc(df, lookback=10):
    o = df.open
    h = df.high
    l = df.low
    c = df.close
    
    k = 0.34 / (1.34 + (lookback+1)/(lookback-1))
    cc = np.log(c/c.shift(1))
    ho = np.log(h/o)
    lo = np.log(l/o)
    co = np.log(c/o)
    oc = np.log(o/c.shift(1))
    oc_sq = oc**2
    cc_sq = cc**2
    rs = ho*(ho-co)+lo*(lo-co)
    close_vol = cc_sq.rolling(lookback).sum() * (1.0 / (lookback - 1.0))
    open_vol = oc_sq.rolling(lookback).sum() * (1.0 / (lookback - 1.0))
    window_rs = rs.rolling(lookback).sum() * (1.0 / (lookback - 1.0))
    result = (open_vol + k * close_vol + (1-k) * window_rs).apply(np.sqrt) * np.sqrt(252)
    result[:lookback-1] = np.nan
    
    return result

# %%
prices["return_close"] = cc

# %% [markdown]
# #### Maximum Drawdown:

# %%
# maximum drawdown

def max_dr():
    x = (1+prices["return_close"]).cumprod()
    previous_peaks = x.cummax()
    drawdown = (x - previous_peaks)/previous_peaks
    
    return drawdown

# %%
drawdown = max_dr()
drawdown.plot.line()
# Out:
# <AxesSubplot:xlabel='ts'>

# %%
prices["volatility"] = vol_ohlc(prices)
prices["max_drawdown"] = drawdown

# %% [markdown]
# #### Plotting:

# %%
# %%capture

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))

# %%
# plotting

def series_plot(data, events=None, ax=None):
    data.plot(ax=ax)
    
    start_of_days = data.between_time('00:00:00', '00:00:00').index.to_list()
    end_of_days = start_of_days[1:] + [data.index[-1]]
    colors = iter(cm.rainbow(np.linspace(0, 1, len(start_of_days))))
    
    for x, y in zip(start_of_days, end_of_days):
        color = next(colors)
        ax.axvspan(x, y, color=color, alpha=0.1)

# %%
series_plot(prices[['return_close']], ax=ax[0, 0])
series_plot(prices[['volatility']], ax=ax[0, 1])
series_plot(prices[['max_drawdown']], ax=ax[1, 0])
series_plot(prices[['close']], ax=ax[1, 1])
fig.suptitle(f'Market action for {token} between {from_date} and {to_date}')
fig

# %%
prices
# Out:
#                         open     high      low    close        volume  \
# ts
# 2021-11-26 00:00:00  4520.77  4555.11  4512.01  4525.87   5931.964221
# 2021-11-26 01:00:00  4527.03  4555.53  4493.42  4501.61   8778.167630
# 2021-11-26 02:00:00  4501.12  4524.03  4489.06  4489.68   6501.617215
# 2021-11-26 03:00:00  4489.23  4504.44  4455.38  4461.07   5350.262486
# 2021-11-26 04:00:00  4460.82  4473.83  4428.32  4429.85   5502.642751
# ...                      ...      ...      ...      ...           ...
# 2021-12-02 19:00:00  4496.68  4498.15  4435.00  4483.59  12659.707261
# 2021-12-02 20:00:00  4483.57  4509.11  4476.16  4490.75   7955.847565
# 2021-12-02 21:00:00  4490.80  4544.04  4472.59  4539.06   9404.595130
# 2021-12-02 22:00:00  4539.51  4556.45  4522.88  4546.65   7666.398809
# 2021-12-02 23:00:00  4546.65  4559.84  4525.00  4545.07   5521.361836
#
#                         volumeUSD token chain  return_close  volatility  \
# ts
# 2021-11-26 00:00:00  2.688868e+07   ETH   ETH           NaN         NaN
# 2021-11-26 01:00:00  3.969569e+07   ETH   ETH     -0.005375         NaN
# 2021-11-26 02:00:00  2.929044e+07   ETH   ETH     -0.002654         NaN
# 2021-11-26 03:00:00  2.401037e+07   ETH   ETH     -0.006393         NaN
# 2021-11-26 04:00:00  2.449721e+07   ETH   ETH     -0.007023         NaN
# ...                           ...   ...   ...           ...         ...
# 2021-12-02 19:00:00  5.651965e+07   ETH   ETH     -0.002820    0.181890
# 2021-12-02 20:00:00  3.574223e+07   ETH   ETH      0.001596    0.179588
# 2021-12-02 21:00:00  4.249628e+07   ETH   ETH      0.010700    0.181279
# 2021-12-02 22:00:00  3.480727e+07   ETH   ETH      0.001671    0.174711
# 2021-12-02 23:00:00  2.506029e+07   ETH   ETH     -0.000348    0.172263
#
#                      max_drawdown
# ts
# 2021-11-26 00:00:00           NaN
# 2021-11-26 01:00:00      0.000000
# 2021-11-26 02:00:00     -0.002654
# 2021-11-26 03:00:00     -0.009029
# 2021-11-26 04:00:00     -0.015989
# ...                           ...
# 2021-12-02 19:00:00     -0.061565
# 2021-12-02 20:00:00     -0.060068
# 2021-12-02 21:00:00     -0.050010
# 2021-12-02 22:00:00     -0.048423
# 2021-12-02 23:00:00     -0.048754
#
# [168 rows x 11 columns]

# %%
sb.glue('token', token)
sb.glue('from_date', from_date)
sb.glue('to_date', to_date)
sb.glue('prices', prices, encoder='pandas')
sb.glue('summary_plot', fig, encoder='display', display=True)
