# %% [markdown]
# # Importing and starting the work on HW2

# %%
import pandas as pd
import numpy as np
import requests

# %%
def get_data_coin(token):
    res = requests.get(
        f'https://api.cryptowat.ch/markets/coinbase-pro/{token}usd/ohlc',
        params={
            'periods': '3600',
            'after': str(int(pd.Timestamp('2021-11-22').timestamp()))
        }
    )

    df = pd.DataFrame(
        res.json()['result']['3600'],
        columns=['ts', 'open', 'high', 'low', 'close', 'volume', 'volumeUSD']
    )
    df['ts'] = pd.to_datetime(df.ts, unit='s')
    df['token'] = token
    
    return df

# %%
tokens = ['ETH', 'SOL', 'AVAX', 'USDT', 'FLOW']

# %%
df_eth = get_data_coin('ETH')
df_sol = get_data_coin('SOL')
df_avax = get_data_coin('AVAX')
df_usdt = get_data_coin('USDT')

# %%
df_usdt.head()
# Out:
#                    ts    open    high     low   close       volume  \
# 0 2021-11-22 00:00:00  1.0010  1.0017  1.0009  1.0012   9987681.09
# 1 2021-11-22 01:00:00  1.0012  1.0014  1.0012  1.0013   7766318.34
# 2 2021-11-22 02:00:00  1.0012  1.0013  1.0011  1.0012   7979323.48
# 3 2021-11-22 03:00:00  1.0012  1.0014  1.0010  1.0011  10681505.84
# 4 2021-11-22 04:00:00  1.0011  1.0011  1.0008  1.0009   3567405.96
#
#       volumeUSD token
# 0  9.999090e+06  USDT
# 1  7.775823e+06  USDT
# 2  7.988793e+06  USDT
# 3  1.069458e+07  USDT
# 4  3.570749e+06  USDT

# %%
def get_data_kraken(token):
    res = requests.get(
        f'https://api.cryptowat.ch/markets/kraken/{token}usd/ohlc',
        params={
            'periods': '3600',
            'after': str(int(pd.Timestamp('2021-11-22').timestamp()))
        }
    )

    df = pd.DataFrame(
        res.json()['result']['3600'],
        columns=['ts', 'open', 'high', 'low', 'close', 'volume', 'volumeUSD']
    )
    df['ts'] = pd.to_datetime(df.ts, unit='s')
    df['token'] = token
    
    return df

# %%
df_flow = get_data_kraken('FLOW')

# %%
df_flow.head()
# Out:
#                    ts    open    high     low   close        volume  \
# 0 2021-11-22 00:00:00  13.887  14.169  13.887  14.150  23261.381369
# 1 2021-11-22 01:00:00  14.053  14.453  13.543  13.621  29108.788932
# 2 2021-11-22 02:00:00  13.534  13.862  13.387  13.753  24737.688935
# 3 2021-11-22 03:00:00  13.753  13.813  13.435  13.652  10224.587462
# 4 2021-11-22 04:00:00  13.652  13.652  13.382  13.581   5998.121286
#
#        volumeUSD token
# 0  327475.506965  FLOW
# 1  411767.484368  FLOW
# 2  338660.037818  FLOW
# 3  139852.146013  FLOW
# 4   81263.038401  FLOW

# %%
df_list = [df_eth, df_sol, df_avax, df_usdt, df_flow]
df_base = pd.concat(df_list)

# %%
df = df_base.set_index('ts')

# %%
df.head()
# Out:
#                         open     high      low    close       volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH

# %% [markdown]
# ## Getting total USD volume traded for each token in a dataframe, sorted from highest volume to lowest volume.

# %%
df.volumeUSD.describe()
# Out:
# count    3.285000e+03
# mean     1.209168e+07
# std      2.052207e+07
# min      1.970443e+01
# 25%      1.562095e+06
# 50%      5.397404e+06
# 75%      1.370922e+07
# max      3.702769e+08
# Name: volumeUSD, dtype: float64

# %%
total_usd_vol_per_token = df.groupby('token').sum().volumeUSD.sort_values(ascending=False)

# %%
total_usd_vol_per_token
# Out:
# token
# ETH     2.484148e+10
# SOL     8.138634e+09
# AVAX    4.398566e+09
# USDT    2.245864e+09
# FLOW    9.661679e+07
# Name: volumeUSD, dtype: float64

# %% [markdown]
# ## Adding a column that calculates the close price ratio between ETH and SOL for each house (i.e. close price of ETH / close price of SOL for each period)

# %%
df
# Out:
#                          open      high       low     close       volume  \
# ts
# 2021-11-22 00:00:00  4317.980  4342.240  4246.070  4262.990  7262.562789
# 2021-11-22 01:00:00  4263.040  4270.340  4212.450  4234.370  8437.946084
# 2021-11-22 02:00:00  4234.870  4246.720  4171.170  4217.890  9259.725370
# 2021-11-22 03:00:00  4217.880  4223.480  4163.580  4193.470  9259.899519
# 2021-11-22 04:00:00  4192.950  4213.590  4147.000  4168.350  7934.546906
# ...                       ...       ...       ...       ...          ...
# 2021-12-19 04:00:00     8.565     8.610     8.565     8.600  1797.236578
# 2021-12-19 05:00:00     8.609     8.630     8.609     8.628  2454.143371
# 2021-12-19 06:00:00     8.617     8.628     8.582     8.593   878.909600
# 2021-12-19 07:00:00     8.580     8.580     8.557     8.566  3754.982212
# 2021-12-19 08:00:00     8.562     8.562     8.562     8.562     2.301382
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH
# ...                           ...   ...
# 2021-12-19 04:00:00  1.544555e+04  FLOW
# 2021-12-19 05:00:00  2.116960e+04  FLOW
# 2021-12-19 06:00:00  7.555117e+03  FLOW
# 2021-12-19 07:00:00  3.217920e+04  FLOW
# 2021-12-19 08:00:00  1.970443e+01  FLOW
#
# [3285 rows x 7 columns]

# %% [markdown]
# ### Tried working with this but didn't work for some reason

# %%
df_token = df.groupby('token')
df[df_token]
# Out:
# /Users/klimyadrintsev/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3s/_b4msy911pd2fxsnmqbwmlnh0000gn/T/ipykernel_30270/1582950128.py in <module>
#       1 df_token = df.groupby('token')
# ----> 2 df[df_token]
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1307
#    1308         if ax._index_as_unique:
# -> 1309             indexer = ax.get_indexer_for(keyarr)
#    1310             keyarr = ax.reindex(keyarr)[0]
#    1311         else:
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    5273         """
#    5274         if self._index_as_unique:
# -> 5275             return self.get_indexer(target, **kwargs)
#    5276         indexer, _ = self.get_indexer_non_unique(target)
#    5277         return indexer
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3484             )
#    3485
# -> 3486         return self._get_indexer(target, method, limit, tolerance)
#    3487
#    3488     def _get_indexer(
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/indexes/base.py in _get_indexer(self, target, method, limit, tolerance)
#    3510             indexer = self._get_nearest_indexer(target, limit, tolerance)
#    3511         else:
# -> 3512             indexer = self._engine.get_indexer(target._get_engine_target())
#    3513
#    3514         return ensure_platform_int(indexer)
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'DataFrame'

# %%
df[(df['token'] == 'ETH') | (df['token'] == 'SOL')]['close', 'token']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('close', 'token')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/3s/_b4msy911pd2fxsnmqbwmlnh0000gn/T/ipykernel_30270/745640180.py in <module>
# ----> 1 df[(df['token'] == 'ETH') | (df['token'] == 'SOL')]['close', 'token']
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: ('close', 'token')

# %%
df[df['token'] == ('ETH', 'SOL')]
# Out:
# Empty DataFrame
# Columns: [open, high, low, close, volume, volumeUSD, token]
# Index: []

# %% [markdown]
# ### Will be trying a new approach for the task

# %%
df_eth_token = df[df['token'] == ('ETH')]
df_eth_token
# Out:
#                         open     high      low    close        volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99   7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37   8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89   9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47   9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35   7934.546906
# ...                      ...      ...      ...      ...           ...
# 2021-12-19 04:00:00  3945.33  4031.71  3945.00  3990.64  10713.408764
# 2021-12-19 05:00:00  3990.63  4039.73  3990.63  4010.91   4960.046194
# 2021-12-19 06:00:00  4010.91  4020.38  3985.13  3990.43   2848.402892
# 2021-12-19 07:00:00  3989.72  3993.15  3970.01  3972.45   2478.724828
# 2021-12-19 08:00:00  3971.14  3983.88  3966.09  3982.56    537.480353
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH
# ...                           ...   ...
# 2021-12-19 04:00:00  4.277069e+07   ETH
# 2021-12-19 05:00:00  1.989931e+07   ETH
# 2021-12-19 06:00:00  1.139783e+07   ETH
# 2021-12-19 07:00:00  9.875826e+06   ETH
# 2021-12-19 08:00:00  2.135953e+06   ETH
#
# [657 rows x 7 columns]

# %%
df_sol_token = df[df['token'] == ('SOL')]
df_sol_token
# Out:
#                         open     high      low    close     volume  \
# ts
# 2021-11-22 00:00:00  230.483  234.688  228.805  230.785  93531.805
# 2021-11-22 01:00:00  230.752  232.269  225.052  226.000  88840.999
# 2021-11-22 02:00:00  225.952  227.996  223.812  227.037  95224.398
# 2021-11-22 03:00:00  227.012  227.485  221.900  223.117  73456.342
# 2021-11-22 04:00:00  223.129  224.545  220.080  220.652  78399.621
# ...                      ...      ...      ...      ...        ...
# 2021-12-19 04:00:00  181.370  184.970  180.690  184.630  55973.706
# 2021-12-19 05:00:00  184.660  186.960  184.270  186.740  42932.460
# 2021-12-19 06:00:00  186.740  187.910  185.450  185.800  41907.455
# 2021-12-19 07:00:00  185.780  187.490  185.580  187.360  22181.303
# 2021-12-19 08:00:00  187.350  187.870  186.990  187.810   4853.559
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  2.172284e+07   SOL
# 2021-11-22 01:00:00  2.017188e+07   SOL
# 2021-11-22 02:00:00  2.153562e+07   SOL
# 2021-11-22 03:00:00  1.646345e+07   SOL
# 2021-11-22 04:00:00  1.742352e+07   SOL
# ...                           ...   ...
# 2021-12-19 04:00:00  1.026771e+07   SOL
# 2021-12-19 05:00:00  7.967289e+06   SOL
# 2021-12-19 06:00:00  7.829859e+06   SOL
# 2021-12-19 07:00:00  4.144035e+06   SOL
# 2021-12-19 08:00:00  9.090932e+05   SOL
#
# [657 rows x 7 columns]

# %%
df_close_eth_sol = (df_eth['close'] / df_sol['close'])
df_close_eth_sol
# Out:
# 0      18.471694
# 1      18.736150
# 2      18.577985
# 3      18.794937
# 4      18.891059
#          ...
# 652    21.614256
# 653    21.478580
# 654    21.477018
# 655    21.202231
# 656    21.205261
# Name: close, Length: 657, dtype: float64

# %%
df_eth[['ts', 'close']]
# Out:
#                      ts    close
# 0   2021-11-22 00:00:00  4262.99
# 1   2021-11-22 01:00:00  4234.37
# 2   2021-11-22 02:00:00  4217.89
# 3   2021-11-22 03:00:00  4193.47
# 4   2021-11-22 04:00:00  4168.35
# ..                  ...      ...
# 652 2021-12-19 04:00:00  3990.64
# 653 2021-12-19 05:00:00  4010.91
# 654 2021-12-19 06:00:00  3990.43
# 655 2021-12-19 07:00:00  3972.45
# 656 2021-12-19 08:00:00  3982.56
#
# [657 rows x 2 columns]

# %%
df_eth_close = df_eth[['ts', 'close']].set_index('ts')
df_sol_close = df_sol[['ts', 'close']].set_index('ts')

df_close_eth_sol = df_eth_close.div(df_sol_close)
df_close_eth_sol
# Out:
#                          close
# ts
# 2021-11-22 00:00:00  18.471694
# 2021-11-22 01:00:00  18.736150
# 2021-11-22 02:00:00  18.577985
# 2021-11-22 03:00:00  18.794937
# 2021-11-22 04:00:00  18.891059
# ...                        ...
# 2021-12-19 04:00:00  21.614256
# 2021-12-19 05:00:00  21.478580
# 2021-12-19 06:00:00  21.477018
# 2021-12-19 07:00:00  21.202231
# 2021-12-19 08:00:00  21.205261
#
# [657 rows x 1 columns]

# %% [markdown]
# ### Not really sure from the assignment whenever this is required

# %%
df_with_eth_sol = df

# %%
df_close_eth_sol['token'] = 'ETH/SOL'

# %%
df_with_eth_sol.append(df_close_eth_sol)
# Out:
#                         open     high      low        close       volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.990000  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.370000  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.890000  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.470000  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.350000  7934.546906
# ...                      ...      ...      ...          ...          ...
# 2021-12-19 04:00:00      NaN      NaN      NaN    21.614256          NaN
# 2021-12-19 05:00:00      NaN      NaN      NaN    21.478580          NaN
# 2021-12-19 06:00:00      NaN      NaN      NaN    21.477018          NaN
# 2021-12-19 07:00:00      NaN      NaN      NaN    21.202231          NaN
# 2021-12-19 08:00:00      NaN      NaN      NaN    21.205261          NaN
#
#                         volumeUSD    token
# ts
# 2021-11-22 00:00:00  3.123077e+07      ETH
# 2021-11-22 01:00:00  3.574586e+07      ETH
# 2021-11-22 02:00:00  3.895639e+07      ETH
# 2021-11-22 03:00:00  3.882032e+07      ETH
# 2021-11-22 04:00:00  3.315476e+07      ETH
# ...                           ...      ...
# 2021-12-19 04:00:00           NaN  ETH/SOL
# 2021-12-19 05:00:00           NaN  ETH/SOL
# 2021-12-19 06:00:00           NaN  ETH/SOL
# 2021-12-19 07:00:00           NaN  ETH/SOL
# 2021-12-19 08:00:00           NaN  ETH/SOL
#
# [3942 rows x 7 columns]

# %% [markdown]
# ## Changing the name of the `volume` and `volumeUSD` columns to `volumeBase` and `volumeTerm`

# %%
df.head()
# Out:
#                         open     high      low    close       volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH

# %%
df_renamed = df.rename(
    columns={
        'volume':'volumeBase',
        'volumeUSD':'volumeTerm'
    }
)

# %%
df_renamed.head()
# Out:
#                         open     high      low    close   volumeBase  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                        volumeTerm token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH

# %% [markdown]
# ## Creating a fat table indexed by the timestamp, and each column is the close price of each token (i.e. this should be a table of  200 rows and 5 columns)

# %%
df.head()
# Out:
#                         open     high      low    close       volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH

# %%
df_close_tokens = df

# %%
df_close_tokens[['close', 'token']]
# Out:
#                         close token
# ts
# 2021-11-22 00:00:00  4262.990   ETH
# 2021-11-22 01:00:00  4234.370   ETH
# 2021-11-22 02:00:00  4217.890   ETH
# 2021-11-22 03:00:00  4193.470   ETH
# 2021-11-22 04:00:00  4168.350   ETH
# ...                       ...   ...
# 2021-12-19 04:00:00     8.600  FLOW
# 2021-12-19 05:00:00     8.628  FLOW
# 2021-12-19 06:00:00     8.593  FLOW
# 2021-12-19 07:00:00     8.566  FLOW
# 2021-12-19 08:00:00     8.562  FLOW
#
# [3285 rows x 2 columns]

# %%
df_close_tokens_seperate = pd.DataFrame()

# %%
df_close_tokens_seperate['ETH'] = df_close_tokens['close'][df_close_tokens['token']=='ETH']
df_close_tokens_seperate['SOL'] = df_close_tokens['close'][df_close_tokens['token']=='SOL']
df_close_tokens_seperate['AVAX'] = df_close_tokens['close'][df_close_tokens['token']=='AVAX']
df_close_tokens_seperate['USDT'] = df_close_tokens['close'][df_close_tokens['token']=='USDT']
df_close_tokens_seperate['FLOW'] = df_close_tokens['close'][df_close_tokens['token']=='FLOW']

# %%
df_close_tokens_seperate
# Out:
#                          ETH      SOL    AVAX    USDT    FLOW
# ts
# 2021-11-22 00:00:00  4262.99  230.785  128.67  1.0012  14.150
# 2021-11-22 01:00:00  4234.37  226.000  134.85  1.0013  13.621
# 2021-11-22 02:00:00  4217.89  227.037  132.54  1.0012  13.753
# 2021-11-22 03:00:00  4193.47  223.117  133.38  1.0011  13.652
# 2021-11-22 04:00:00  4168.35  220.652  136.29  1.0009  13.581
# ...                      ...      ...     ...     ...     ...
# 2021-12-19 04:00:00  3990.64  184.630  115.09  1.0004   8.600
# 2021-12-19 05:00:00  4010.91  186.740  114.73  1.0004   8.628
# 2021-12-19 06:00:00  3990.43  185.800  113.62  1.0004   8.593
# 2021-12-19 07:00:00  3972.45  187.360  113.60  1.0002   8.566
# 2021-12-19 08:00:00  3982.56  187.810  114.15  1.0003   8.562
#
# [657 rows x 5 columns]

# %%
df_log_return = df_close_tokens_seperate

# %%
df_log_return['ETH'][0]
# Out:
# 4262.99

# %%
df_log_return
# Out:
#                          ETH      SOL    AVAX    USDT    FLOW
# ts
# 2021-11-22 00:00:00  4262.99  230.785  128.67  1.0012  14.150
# 2021-11-22 01:00:00  4234.37  226.000  134.85  1.0013  13.621
# 2021-11-22 02:00:00  4217.89  227.037  132.54  1.0012  13.753
# 2021-11-22 03:00:00  4193.47  223.117  133.38  1.0011  13.652
# 2021-11-22 04:00:00  4168.35  220.652  136.29  1.0009  13.581
# ...                      ...      ...     ...     ...     ...
# 2021-12-19 04:00:00  3990.64  184.630  115.09  1.0004   8.600
# 2021-12-19 05:00:00  4010.91  186.740  114.73  1.0004   8.628
# 2021-12-19 06:00:00  3990.43  185.800  113.62  1.0004   8.593
# 2021-12-19 07:00:00  3972.45  187.360  113.60  1.0002   8.566
# 2021-12-19 08:00:00  3982.56  187.810  114.15  1.0003   8.562
#
# [657 rows x 5 columns]

# %%
for token in df_log_return.columns:
    df_log_return[token + '_log_return'] = np.nan
    for i in range(1,len(df_log_return)):
        df_log_return[token + '_log_return'][i] = np.log(df_log_return[token][i] / [df_log_return[token][i-1]])

# %%
df_log_return
# Out:
#                          ETH      SOL    AVAX    USDT    FLOW  ETH_log_return  \
# ts
# 2021-11-22 00:00:00  4262.99  230.785  128.67  1.0012  14.150             NaN
# 2021-11-22 01:00:00  4234.37  226.000  134.85  1.0013  13.621       -0.006736
# 2021-11-22 02:00:00  4217.89  227.037  132.54  1.0012  13.753       -0.003900
# 2021-11-22 03:00:00  4193.47  223.117  133.38  1.0011  13.652       -0.005806
# 2021-11-22 04:00:00  4168.35  220.652  136.29  1.0009  13.581       -0.006008
# ...                      ...      ...     ...     ...     ...             ...
# 2021-12-19 04:00:00  3990.64  184.630  115.09  1.0004   8.600        0.011467
# 2021-12-19 05:00:00  4010.91  186.740  114.73  1.0004   8.628        0.005067
# 2021-12-19 06:00:00  3990.43  185.800  113.62  1.0004   8.593       -0.005119
# 2021-12-19 07:00:00  3972.45  187.360  113.60  1.0002   8.566       -0.004516
# 2021-12-19 08:00:00  3982.56  187.810  114.15  1.0003   8.562        0.002542
#
#                      SOL_log_return  AVAX_log_return  USDT_log_return  \
# ts
# 2021-11-22 00:00:00             NaN              NaN              NaN
# 2021-11-22 01:00:00       -0.020952         0.046912           0.0001
# 2021-11-22 02:00:00        0.004578        -0.017279          -0.0001
# 2021-11-22 03:00:00       -0.017417         0.006318          -0.0001
# 2021-11-22 04:00:00       -0.011109         0.021583          -0.0002
# ...                             ...              ...              ...
# 2021-12-19 04:00:00        0.017649         0.002871           0.0000
# 2021-12-19 05:00:00        0.011363        -0.003133           0.0000
# 2021-12-19 06:00:00       -0.005046        -0.009722           0.0000
# 2021-12-19 07:00:00        0.008361        -0.000176          -0.0002
# 2021-12-19 08:00:00        0.002399         0.004830           0.0001
#
#                      FLOW_log_return
# ts
# 2021-11-22 00:00:00              NaN
# 2021-11-22 01:00:00        -0.038102
# 2021-11-22 02:00:00         0.009644
# 2021-11-22 03:00:00        -0.007371
# 2021-11-22 04:00:00        -0.005214
# ...                              ...
# 2021-12-19 04:00:00         0.005480
# 2021-12-19 05:00:00         0.003251
# 2021-12-19 06:00:00        -0.004065
# 2021-12-19 07:00:00        -0.003147
# 2021-12-19 08:00:00        -0.000467
#
# [657 rows x 10 columns]

# %%
for token in df_log_return.columns:
    [token +'_mean'] = df_log_return[token + '_log_return'].mean()
# Out:
#   File "/var/folders/3s/_b4msy911pd2fxsnmqbwmlnh0000gn/T/ipykernel_30270/1554505083.py", line 2
#     [token +'_mean'] = df_log_return[token + '_log_return'].mean()
#     ^
# SyntaxError: cannot assign to operator

# %%
df_log_return.fillna(
    for token in df_log_return.columns:
        df_log_return[token + '_log_return'].mean())
# Out:
#   File "/var/folders/3s/_b4msy911pd2fxsnmqbwmlnh0000gn/T/ipykernel_30270/1335092893.py", line 1
#     df_log_return.fillna(for token in df_log_return.columns:df_log_return[token + '_log_return'].mean())
#                          ^
# SyntaxError: invalid syntax

# %%
df_log_return.columns[5:].tolist()
# Out:
# ['ETH_log_return',
#  'SOL_log_return',
#  'AVAX_log_return',
#  'USDT_log_return',
#  'FLOW_log_return']

# %%
df_log_return[df_log_return.columns[5:].tolist()].corr
# Out:
# <bound method DataFrame.corr of                      ETH_log_return  SOL_log_return  AVAX_log_return  \
# ts
# 2021-11-22 00:00:00             NaN             NaN              NaN
# 2021-11-22 01:00:00       -0.006736       -0.020952         0.046912
# 2021-11-22 02:00:00       -0.003900        0.004578        -0.017279
# 2021-11-22 03:00:00       -0.005806       -0.017417         0.006318
# 2021-11-22 04:00:00       -0.006008       -0.011109         0.021583
# ...                             ...             ...              ...
# 2021-12-19 04:00:00        0.011467        0.017649         0.002871
# 2021-12-19 05:00:00        0.005067        0.011363        -0.003133
# 2021-12-19 06:00:00       -0.005119       -0.005046        -0.009722
# 2021-12-19 07:00:00       -0.004516        0.008361        -0.000176
# 2021-12-19 08:00:00        0.002542        0.002399         0.004830
#
#                      USDT_log_return  FLOW_log_return
# ts
# 2021-11-22 00:00:00              NaN              NaN
# 2021-11-22 01:00:00           0.0001        -0.038102
# 2021-11-22 02:00:00          -0.0001         0.009644
# 2021-11-22 03:00:00          -0.0001        -0.007371
# 2021-11-22 04:00:00          -0.0002        -0.005214
# ...                              ...              ...
# 2021-12-19 04:00:00           0.0000         0.005480
# 2021-12-19 05:00:00           0.0000         0.003251
# 2021-12-19 06:00:00           0.0000        -0.004065
# 2021-12-19 07:00:00          -0.0002        -0.003147
# 2021-12-19 08:00:00           0.0001        -0.000467
#
# [657 rows x 5 columns]>
